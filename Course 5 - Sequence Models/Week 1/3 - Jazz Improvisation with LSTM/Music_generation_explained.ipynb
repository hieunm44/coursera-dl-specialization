# %% [markdown]
# # Music Generation

# %%
import IPython
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from data_utils import load_music_utils, generate_music, mid2wav

from tensorflow.keras.layers import Dense, Input, LSTM, Reshape 
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ## 1. Dataset

# %%
X, Y, n_values, indices_values, chords = load_music_utils('data/original_metheny.mid')
# X.shape=(m, T_x, n_x)=(60, 30, 90). Ở đây m là số lượng tranining samples (ko phải batch size), nghĩa là chỉ có 60 samples trong dataset;
# T_x là số lượng musical values trong mỗi sample, nghĩa là độ dài đoạn nhạc; 
# n_x là độ dài mỗi musical value, là một one-hot vector
# Y.shape=(T_y, m, n_y)=(30, 60, 90). Y giống hệt X nhưng đc dịch forward đi 1
# n_values=90: Số lượng unique musical values trong dataset. Thực ra ở đây n_values=n_x=n_y
# indices_values={0: 'R,0.250', 1: 'R,0.417', ..., 89: 'S,0.250,<d2,A-4>'}: len=90, dict để map integers từ 0-89 tới musical values
# chords=OrderedDict([(0, [<music21.instrument.Piano 'Piano: Piano'>, ...]), ...]): len=19, Hợp âm đc dùng trong input midi
print('number of training examples:', X.shape[0])
print('Tx (length of sequence):', X.shape[1])
print('total # of unique values:', n_values)
print('shape of X:', X.shape)
print('Shape of Y:', Y.shape)
print('Number of chords', len(chords))
# Out:
# number of training examples: 60
# Tx (length of sequence): 30
# total # of unique values: 90
# shape of X: (60, 30, 90)
# Shape of Y: (30, 60, 90)
# Number of chords 19

# %% [markdown]
# ## 2. Model
#
# <img src="images/music_generation.png" height=500/>

# %%
# number of dimensions for the hidden state of each LSTM cell.
n_a = 64 
m = 60
a0 = np.zeros((m, n_a))
c0 = np.zeros((m, n_a))

n_values = 90 # number of music values
# Các layers để dùng trong djmodel
reshaper = Reshape((1, n_values))                  
LSTM_cell = LSTM(n_a, return_state = True)        
densor = Dense(n_values, activation='softmax')    


def djmodel(Tx, LSTM_cell, densor, reshaper):
    # Get the shape of input values
    n_values = densor.units
    
    # Get the number of the hidden state vector
    n_a = LSTM_cell.units
    
    # Define the input layer and specify the shape
    X = Input(shape=(Tx, n_values)) 
    
    # Define the initial hidden state a0 and initial cell state c0
    # using `Input`
    a0 = Input(shape=(n_a,), name='a0')
    c0 = Input(shape=(n_a,), name='c0')
    a = a0
    c = c0
    # Step 1: Create empty list to append the outputs while you iterate (≈1 line)
    outputs = []
    
    # Từ đây m là batch_size=32
    # Step 2: Loop over tx
    for t in range(Tx): # Tại một time step t
        # Lấy ra x^t là X[:, t, :], có shape (m, 1, n_x)=(32, 1, 90)
        # Step 2.A: select the "t"th time step vector from X. 
        x = X[:, t, :]

        # Step 2.B: Use reshaper to reshape x to be (1, n_values) (≈1 line)
        x = reshaper(x) # x,shape=(32, 90)

        # Đưa x^t, a^{t-1}, c^{t-1} vào LSTM cell để tính a^t, c^t, đều có shape (m, n_a)=(32, 64)
        # Step 2.C: Perform one step of the LSTM_cell
        _, a, c = LSTM_cell(x, initial_state=[a, c]) # LSTM cell trả về output state y^t, hidden state a^t, cell state c^t. Ở đây return_sequences=False nên y^t=a^t.
        # return_sequences: False: Chỉ trả về y^t cuối cùng, sẽ có shape (m, n_a); True: Trả về tất cẩ y^t, sẽ có shape (m, T_y, n_a). Ở đây ta đang lặp từng time step nên đặt return_sequences=False
        # return_state: Có trả về hidden state a^t và cell state c^t cuối cùng hay ko
        
        # Tính y^t
        # Step 2.D: Apply densor to the hidden state output of LSTM_Cell
        out = densor(a) # out.shape=(m, n_y)=(m, 90)
        
        # Step 2.E: append the output to "outputs"
        outputs.append(out)

    # Đến đây outputs có len T_y=30, mỗi element có shape (m, n_y)=(32, 90)    
    # Step 3: Create model instance
    model = Model(inputs=[X, a0, c0], outputs=outputs)

    
    return model

# %%
model = djmodel(Tx=30, LSTM_cell=LSTM_cell, densor=densor, reshaper=reshaper)
# model.summary()
# Out:
# <KerasTensor shape=(None, 64), dtype=float32, sparse=False, name=keras_tensor_4794>
# <KerasTensor shape=(None, 64), dtype=float32, sparse=False, name=keras_tensor_4795>
# <KerasTensor shape=(None, 64), dtype=float32, sparse=False, name=keras_tensor_4796>

# %%
opt = Adam(learning_rate=0.01, beta_1=0.9, beta_2=0.999, weight_decay=0.01)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy']*30)

# %%
history = model.fit([X, a0, c0], list(Y), epochs=100, verbose=1)
# default batch_size là 32 nên sẽ có 2 batches
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - dense_30_accuracy: 0.0333 - dense_30_accuracy_1: 0.0549 - dense_30_accuracy_10: 0.0111 - dense_30_accuracy_11: 0.0333 - dense_30_accuracy_12: 0.0660 - dense_30_accuracy_13: 0.0556 - dense_30_accuracy_14: 0.0333 - dense_30_accuracy_15: 0.0660 - dense_30_accuracy_16: 0.0667 - dense_30_accuracy_17: 0.0111 - dense_30_accuracy_18: 0.0549 - dense_30_accuracy_19: 0.0222 - dense_30_accuracy_2: 0.0542 - dense_30_accuracy_20: 0.0556 - dense_30_accuracy_21: 0.0556 - dense_30_accuracy_22: 0.0333 - dense_30_accuracy_23: 0.1090 - dense_30_accuracy_24: 0.0444 - dense_30_accuracy_25: 0.0771 - dense_30_accuracy_26: 0.0875 - dense_30_accuracy_27: 0.0333 - dense_30_accuracy_28: 0.0549 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.0549 - dense_30_accuracy_4: 0.0333 - dense_30_accuracy_5: 0.0667 - dense_30_accuracy_6: 0.0111 - dense_30_accuracy_7: 0.0986 - dense_30_accuracy_8: 0.0667 - dense_30_accuracy_9: 0.0667 - dense_30_loss: 0.0000e+00 - loss: 130.2285
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dense_30_accuracy: 0.0972 - dense_30_accuracy_1: 0.2278 - dense_30_accuracy_10: 0.1076 - dense_30_accuracy_11: 0.1847 - dense_30_accuracy_12: 0.1403 - dense_30_accuracy_13: 0.1410 - dense_30_accuracy_14: 0.1729 - dense_30_accuracy_15: 0.1528 - dense_30_accuracy_16: 0.1521 - dense_30_accuracy_17: 0.0437 - dense_30_accuracy_18: 0.0972 - dense_30_accuracy_19: 0.0764 - dense_30_accuracy_2: 0.1736 - dense_30_accuracy_20: 0.0868 - dense_30_accuracy_21: 0.0757 - dense_30_accuracy_22: 0.1514 - dense_30_accuracy_23: 0.1299 - dense_30_accuracy_24: 0.1187 - dense_30_accuracy_25: 0.1076 - dense_30_accuracy_26: 0.1403 - dense_30_accuracy_27: 0.1292 - dense_30_accuracy_28: 0.1187 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1632 - dense_30_accuracy_4: 0.1194 - dense_30_accuracy_5: 0.0986 - dense_30_accuracy_6: 0.1840 - dense_30_accuracy_7: 0.2062 - dense_30_accuracy_8: 0.1736 - dense_30_accuracy_9: 0.1729 - dense_30_loss: 0.0000e+00 - loss: 125.9892
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dense_30_accuracy: 0.0972 - dense_30_accuracy_1: 0.2826 - dense_30_accuracy_10: 0.0326 - dense_30_accuracy_11: 0.1306 - dense_30_accuracy_12: 0.1083 - dense_30_accuracy_13: 0.0875 - dense_30_accuracy_14: 0.1299 - dense_30_accuracy_15: 0.1306 - dense_30_accuracy_16: 0.1187 - dense_30_accuracy_17: 0.0542 - dense_30_accuracy_18: 0.0653 - dense_30_accuracy_19: 0.0868 - dense_30_accuracy_2: 0.1653 - dense_30_accuracy_20: 0.0437 - dense_30_accuracy_21: 0.0542 - dense_30_accuracy_22: 0.0979 - dense_30_accuracy_23: 0.0653 - dense_30_accuracy_24: 0.0646 - dense_30_accuracy_25: 0.0542 - dense_30_accuracy_26: 0.0653 - dense_30_accuracy_27: 0.0875 - dense_30_accuracy_28: 0.0868 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1410 - dense_30_accuracy_4: 0.0757 - dense_30_accuracy_5: 0.0444 - dense_30_accuracy_6: 0.0437 - dense_30_accuracy_7: 0.0764 - dense_30_accuracy_8: 0.0431 - dense_30_accuracy_9: 0.0868 - dense_30_loss: 0.0000e+00 - loss: 117.3603
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dense_30_accuracy: 0.0979 - dense_30_accuracy_1: 0.3021 - dense_30_accuracy_10: 0.0326 - dense_30_accuracy_11: 0.1090 - dense_30_accuracy_12: 0.0333 - dense_30_accuracy_13: 0.2062 - dense_30_accuracy_14: 0.0771 - dense_30_accuracy_15: 0.1417 - dense_30_accuracy_16: 0.1847 - dense_30_accuracy_17: 0.1097 - dense_30_accuracy_18: 0.0986 - dense_30_accuracy_19: 0.0861 - dense_30_accuracy_2: 0.1201 - dense_30_accuracy_20: 0.0875 - dense_30_accuracy_21: 0.1729 - dense_30_accuracy_22: 0.0757 - dense_30_accuracy_23: 0.0549 - dense_30_accuracy_24: 0.0549 - dense_30_accuracy_25: 0.1187 - dense_30_accuracy_26: 0.0653 - dense_30_accuracy_27: 0.1736 - dense_30_accuracy_28: 0.1521 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1729 - dense_30_accuracy_4: 0.2069 - dense_30_accuracy_5: 0.0868 - dense_30_accuracy_6: 0.1625 - dense_30_accuracy_7: 0.1944 - dense_30_accuracy_8: 0.1632 - dense_30_accuracy_9: 0.0653 - dense_30_loss: 0.0000e+00 - loss: 113.4296
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dense_30_accuracy: 0.0771 - dense_30_accuracy_1: 0.1090 - dense_30_accuracy_10: 0.0431 - dense_30_accuracy_11: 0.1090 - dense_30_accuracy_12: 0.0333 - dense_30_accuracy_13: 0.2167 - dense_30_accuracy_14: 0.1187 - dense_30_accuracy_15: 0.1729 - dense_30_accuracy_16: 0.1743 - dense_30_accuracy_17: 0.1201 - dense_30_accuracy_18: 0.1090 - dense_30_accuracy_19: 0.0653 - dense_30_accuracy_2: 0.0646 - dense_30_accuracy_20: 0.1083 - dense_30_accuracy_21: 0.1521 - dense_30_accuracy_22: 0.0653 - dense_30_accuracy_23: 0.0757 - dense_30_accuracy_24: 0.0549 - dense_30_accuracy_25: 0.0979 - dense_30_accuracy_26: 0.0653 - dense_30_accuracy_27: 0.1736 - dense_30_accuracy_28: 0.1417 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.0861 - dense_30_accuracy_4: 0.1417 - dense_30_accuracy_5: 0.0757 - dense_30_accuracy_6: 0.1313 - dense_30_accuracy_7: 0.1833 - dense_30_accuracy_8: 0.1424 - dense_30_accuracy_9: 0.0653 - dense_30_loss: 0.0000e+00 - loss: 111.5700
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dense_30_accuracy: 0.0875 - dense_30_accuracy_1: 0.1187 - dense_30_accuracy_10: 0.0326 - dense_30_accuracy_11: 0.1194 - dense_30_accuracy_12: 0.0653 - dense_30_accuracy_13: 0.2174 - dense_30_accuracy_14: 0.1083 - dense_30_accuracy_15: 0.1313 - dense_30_accuracy_16: 0.1958 - dense_30_accuracy_17: 0.1840 - dense_30_accuracy_18: 0.1201 - dense_30_accuracy_19: 0.0757 - dense_30_accuracy_2: 0.0437 - dense_30_accuracy_20: 0.1201 - dense_30_accuracy_21: 0.1625 - dense_30_accuracy_22: 0.0979 - dense_30_accuracy_23: 0.0653 - dense_30_accuracy_24: 0.0771 - dense_30_accuracy_25: 0.1194 - dense_30_accuracy_26: 0.0771 - dense_30_accuracy_27: 0.1743 - dense_30_accuracy_28: 0.1736 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.0861 - dense_30_accuracy_4: 0.1417 - dense_30_accuracy_5: 0.0861 - dense_30_accuracy_6: 0.1521 - dense_30_accuracy_7: 0.1521 - dense_30_accuracy_8: 0.1632 - dense_30_accuracy_9: 0.0549 - dense_30_loss: 0.0000e+00 - loss: 110.0272
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.1417 - dense_30_accuracy_10: 0.0326 - dense_30_accuracy_11: 0.1410 - dense_30_accuracy_12: 0.0764 - dense_30_accuracy_13: 0.2167 - dense_30_accuracy_14: 0.0556 - dense_30_accuracy_15: 0.1417 - dense_30_accuracy_16: 0.1639 - dense_30_accuracy_17: 0.1625 - dense_30_accuracy_18: 0.0986 - dense_30_accuracy_19: 0.0653 - dense_30_accuracy_2: 0.0437 - dense_30_accuracy_20: 0.1313 - dense_30_accuracy_21: 0.1194 - dense_30_accuracy_22: 0.1097 - dense_30_accuracy_23: 0.0875 - dense_30_accuracy_24: 0.0771 - dense_30_accuracy_25: 0.1090 - dense_30_accuracy_26: 0.1104 - dense_30_accuracy_27: 0.1514 - dense_30_accuracy_28: 0.1736 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.0549 - dense_30_accuracy_4: 0.1729 - dense_30_accuracy_5: 0.0549 - dense_30_accuracy_6: 0.1417 - dense_30_accuracy_7: 0.1417 - dense_30_accuracy_8: 0.1854 - dense_30_accuracy_9: 0.0979 - dense_30_loss: 0.0000e+00 - loss: 109.1589
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dense_30_accuracy: 0.0979 - dense_30_accuracy_1: 0.1639 - dense_30_accuracy_10: 0.0542 - dense_30_accuracy_11: 0.1306 - dense_30_accuracy_12: 0.1625 - dense_30_accuracy_13: 0.1639 - dense_30_accuracy_14: 0.1090 - dense_30_accuracy_15: 0.2062 - dense_30_accuracy_16: 0.2069 - dense_30_accuracy_17: 0.1944 - dense_30_accuracy_18: 0.1306 - dense_30_accuracy_19: 0.1194 - dense_30_accuracy_2: 0.0444 - dense_30_accuracy_20: 0.1417 - dense_30_accuracy_21: 0.1306 - dense_30_accuracy_22: 0.1313 - dense_30_accuracy_23: 0.0979 - dense_30_accuracy_24: 0.1410 - dense_30_accuracy_25: 0.1410 - dense_30_accuracy_26: 0.1306 - dense_30_accuracy_27: 0.1847 - dense_30_accuracy_28: 0.1847 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.0757 - dense_30_accuracy_4: 0.1840 - dense_30_accuracy_5: 0.0764 - dense_30_accuracy_6: 0.1736 - dense_30_accuracy_7: 0.1431 - dense_30_accuracy_8: 0.1847 - dense_30_accuracy_9: 0.1194 - dense_30_loss: 0.0000e+00 - loss: 106.6152
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dense_30_accuracy: 0.0979 - dense_30_accuracy_1: 0.1861 - dense_30_accuracy_10: 0.0549 - dense_30_accuracy_11: 0.1625 - dense_30_accuracy_12: 0.1736 - dense_30_accuracy_13: 0.1736 - dense_30_accuracy_14: 0.1083 - dense_30_accuracy_15: 0.1854 - dense_30_accuracy_16: 0.2618 - dense_30_accuracy_17: 0.2056 - dense_30_accuracy_18: 0.1736 - dense_30_accuracy_19: 0.1083 - dense_30_accuracy_2: 0.1076 - dense_30_accuracy_20: 0.2062 - dense_30_accuracy_21: 0.1646 - dense_30_accuracy_22: 0.2062 - dense_30_accuracy_23: 0.1528 - dense_30_accuracy_24: 0.1313 - dense_30_accuracy_25: 0.1951 - dense_30_accuracy_26: 0.1965 - dense_30_accuracy_27: 0.1514 - dense_30_accuracy_28: 0.2167 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1194 - dense_30_accuracy_4: 0.1632 - dense_30_accuracy_5: 0.1299 - dense_30_accuracy_6: 0.1854 - dense_30_accuracy_7: 0.1743 - dense_30_accuracy_8: 0.1757 - dense_30_accuracy_9: 0.1090 - dense_30_loss: 0.0000e+00 - loss: 104.1331
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dense_30_accuracy: 0.0875 - dense_30_accuracy_1: 0.1965 - dense_30_accuracy_10: 0.0986 - dense_30_accuracy_11: 0.1736 - dense_30_accuracy_12: 0.1965 - dense_30_accuracy_13: 0.2611 - dense_30_accuracy_14: 0.1097 - dense_30_accuracy_15: 0.1854 - dense_30_accuracy_16: 0.1965 - dense_30_accuracy_17: 0.1944 - dense_30_accuracy_18: 0.1958 - dense_30_accuracy_19: 0.0875 - dense_30_accuracy_2: 0.0771 - dense_30_accuracy_20: 0.1083 - dense_30_accuracy_21: 0.1646 - dense_30_accuracy_22: 0.1104 - dense_30_accuracy_23: 0.1097 - dense_30_accuracy_24: 0.1306 - dense_30_accuracy_25: 0.1750 - dense_30_accuracy_26: 0.0986 - dense_30_accuracy_27: 0.1958 - dense_30_accuracy_28: 0.1972 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1090 - dense_30_accuracy_4: 0.2382 - dense_30_accuracy_5: 0.1299 - dense_30_accuracy_6: 0.1639 - dense_30_accuracy_7: 0.1743 - dense_30_accuracy_8: 0.2285 - dense_30_accuracy_9: 0.0979 - dense_30_loss: 0.0000e+00 - loss: 102.3559
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dense_30_accuracy: 0.0875 - dense_30_accuracy_1: 0.2285 - dense_30_accuracy_10: 0.1514 - dense_30_accuracy_11: 0.2062 - dense_30_accuracy_12: 0.2819 - dense_30_accuracy_13: 0.1194 - dense_30_accuracy_14: 0.1958 - dense_30_accuracy_15: 0.3681 - dense_30_accuracy_16: 0.2188 - dense_30_accuracy_17: 0.2174 - dense_30_accuracy_18: 0.2188 - dense_30_accuracy_19: 0.1417 - dense_30_accuracy_2: 0.1625 - dense_30_accuracy_20: 0.2292 - dense_30_accuracy_21: 0.1861 - dense_30_accuracy_22: 0.3042 - dense_30_accuracy_23: 0.2812 - dense_30_accuracy_24: 0.2597 - dense_30_accuracy_25: 0.3146 - dense_30_accuracy_26: 0.1743 - dense_30_accuracy_27: 0.2167 - dense_30_accuracy_28: 0.3035 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1090 - dense_30_accuracy_4: 0.2819 - dense_30_accuracy_5: 0.1847 - dense_30_accuracy_6: 0.2708 - dense_30_accuracy_7: 0.1646 - dense_30_accuracy_8: 0.2167 - dense_30_accuracy_9: 0.1528 - dense_30_loss: 0.0000e+00 - loss: 98.7503
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - dense_30_accuracy: 0.1187 - dense_30_accuracy_1: 0.2181 - dense_30_accuracy_10: 0.0972 - dense_30_accuracy_11: 0.1736 - dense_30_accuracy_12: 0.1417 - dense_30_accuracy_13: 0.1632 - dense_30_accuracy_14: 0.2812 - dense_30_accuracy_15: 0.2826 - dense_30_accuracy_16: 0.2500 - dense_30_accuracy_17: 0.1743 - dense_30_accuracy_18: 0.1639 - dense_30_accuracy_19: 0.1306 - dense_30_accuracy_2: 0.0979 - dense_30_accuracy_20: 0.2174 - dense_30_accuracy_21: 0.1965 - dense_30_accuracy_22: 0.2396 - dense_30_accuracy_23: 0.1743 - dense_30_accuracy_24: 0.2375 - dense_30_accuracy_25: 0.1861 - dense_30_accuracy_26: 0.1514 - dense_30_accuracy_27: 0.1639 - dense_30_accuracy_28: 0.2174 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1194 - dense_30_accuracy_4: 0.2812 - dense_30_accuracy_5: 0.1528 - dense_30_accuracy_6: 0.2069 - dense_30_accuracy_7: 0.2708 - dense_30_accuracy_8: 0.2500 - dense_30_accuracy_9: 0.1639 - dense_30_loss: 0.0000e+00 - loss: 96.0145
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.2181 - dense_30_accuracy_10: 0.1194 - dense_30_accuracy_11: 0.2389 - dense_30_accuracy_12: 0.2507 - dense_30_accuracy_13: 0.2174 - dense_30_accuracy_14: 0.3132 - dense_30_accuracy_15: 0.2514 - dense_30_accuracy_16: 0.3153 - dense_30_accuracy_17: 0.2507 - dense_30_accuracy_18: 0.2493 - dense_30_accuracy_19: 0.1847 - dense_30_accuracy_2: 0.1417 - dense_30_accuracy_20: 0.2285 - dense_30_accuracy_21: 0.2389 - dense_30_accuracy_22: 0.3257 - dense_30_accuracy_23: 0.1979 - dense_30_accuracy_24: 0.2597 - dense_30_accuracy_25: 0.2715 - dense_30_accuracy_26: 0.1743 - dense_30_accuracy_27: 0.2604 - dense_30_accuracy_28: 0.3257 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1299 - dense_30_accuracy_4: 0.2931 - dense_30_accuracy_5: 0.1743 - dense_30_accuracy_6: 0.2403 - dense_30_accuracy_7: 0.3035 - dense_30_accuracy_8: 0.2500 - dense_30_accuracy_9: 0.2174 - dense_30_loss: 0.0000e+00 - loss: 92.5472
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dense_30_accuracy: 0.0771 - dense_30_accuracy_1: 0.2924 - dense_30_accuracy_10: 0.1201 - dense_30_accuracy_11: 0.2514 - dense_30_accuracy_12: 0.2382 - dense_30_accuracy_13: 0.2299 - dense_30_accuracy_14: 0.2701 - dense_30_accuracy_15: 0.2944 - dense_30_accuracy_16: 0.3035 - dense_30_accuracy_17: 0.2396 - dense_30_accuracy_18: 0.2493 - dense_30_accuracy_19: 0.2049 - dense_30_accuracy_2: 0.1201 - dense_30_accuracy_20: 0.2396 - dense_30_accuracy_21: 0.2938 - dense_30_accuracy_22: 0.2833 - dense_30_accuracy_23: 0.2389 - dense_30_accuracy_24: 0.2396 - dense_30_accuracy_25: 0.2819 - dense_30_accuracy_26: 0.2062 - dense_30_accuracy_27: 0.3472 - dense_30_accuracy_28: 0.3375 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1410 - dense_30_accuracy_4: 0.2944 - dense_30_accuracy_5: 0.2174 - dense_30_accuracy_6: 0.2708 - dense_30_accuracy_7: 0.2507 - dense_30_accuracy_8: 0.2708 - dense_30_accuracy_9: 0.1750 - dense_30_loss: 0.0000e+00 - loss: 89.5840
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dense_30_accuracy: 0.0979 - dense_30_accuracy_1: 0.2611 - dense_30_accuracy_10: 0.1306 - dense_30_accuracy_11: 0.2931 - dense_30_accuracy_12: 0.2715 - dense_30_accuracy_13: 0.2396 - dense_30_accuracy_14: 0.1861 - dense_30_accuracy_15: 0.3042 - dense_30_accuracy_16: 0.2736 - dense_30_accuracy_17: 0.3035 - dense_30_accuracy_18: 0.2062 - dense_30_accuracy_19: 0.1521 - dense_30_accuracy_2: 0.1528 - dense_30_accuracy_20: 0.2174 - dense_30_accuracy_21: 0.2708 - dense_30_accuracy_22: 0.2938 - dense_30_accuracy_23: 0.2500 - dense_30_accuracy_24: 0.3042 - dense_30_accuracy_25: 0.2611 - dense_30_accuracy_26: 0.1750 - dense_30_accuracy_27: 0.3368 - dense_30_accuracy_28: 0.3368 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1201 - dense_30_accuracy_4: 0.3583 - dense_30_accuracy_5: 0.2389 - dense_30_accuracy_6: 0.2500 - dense_30_accuracy_7: 0.2931 - dense_30_accuracy_8: 0.2389 - dense_30_accuracy_9: 0.2486 - dense_30_loss: 0.0000e+00 - loss: 86.3462
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dense_30_accuracy: 0.1187 - dense_30_accuracy_1: 0.2403 - dense_30_accuracy_10: 0.1299 - dense_30_accuracy_11: 0.2812 - dense_30_accuracy_12: 0.3042 - dense_30_accuracy_13: 0.2069 - dense_30_accuracy_14: 0.2396 - dense_30_accuracy_15: 0.3576 - dense_30_accuracy_16: 0.3806 - dense_30_accuracy_17: 0.2931 - dense_30_accuracy_18: 0.3146 - dense_30_accuracy_19: 0.2285 - dense_30_accuracy_2: 0.1424 - dense_30_accuracy_20: 0.2500 - dense_30_accuracy_21: 0.2597 - dense_30_accuracy_22: 0.2819 - dense_30_accuracy_23: 0.2181 - dense_30_accuracy_24: 0.2924 - dense_30_accuracy_25: 0.2396 - dense_30_accuracy_26: 0.2174 - dense_30_accuracy_27: 0.2826 - dense_30_accuracy_28: 0.3903 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.0993 - dense_30_accuracy_4: 0.3792 - dense_30_accuracy_5: 0.2826 - dense_30_accuracy_6: 0.3042 - dense_30_accuracy_7: 0.2722 - dense_30_accuracy_8: 0.2722 - dense_30_accuracy_9: 0.2618 - dense_30_loss: 0.0000e+00 - loss: 82.9032
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dense_30_accuracy: 0.0979 - dense_30_accuracy_1: 0.2611 - dense_30_accuracy_10: 0.1625 - dense_30_accuracy_11: 0.2611 - dense_30_accuracy_12: 0.2938 - dense_30_accuracy_13: 0.1847 - dense_30_accuracy_14: 0.2931 - dense_30_accuracy_15: 0.3583 - dense_30_accuracy_16: 0.3806 - dense_30_accuracy_17: 0.3153 - dense_30_accuracy_18: 0.3472 - dense_30_accuracy_19: 0.1854 - dense_30_accuracy_2: 0.1632 - dense_30_accuracy_20: 0.3264 - dense_30_accuracy_21: 0.2826 - dense_30_accuracy_22: 0.2618 - dense_30_accuracy_23: 0.2382 - dense_30_accuracy_24: 0.2604 - dense_30_accuracy_25: 0.2500 - dense_30_accuracy_26: 0.2604 - dense_30_accuracy_27: 0.3139 - dense_30_accuracy_28: 0.3167 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1306 - dense_30_accuracy_4: 0.3688 - dense_30_accuracy_5: 0.3264 - dense_30_accuracy_6: 0.3576 - dense_30_accuracy_7: 0.3576 - dense_30_accuracy_8: 0.2722 - dense_30_accuracy_9: 0.2715 - dense_30_loss: 0.0000e+00 - loss: 79.5733
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.2403 - dense_30_accuracy_10: 0.2285 - dense_30_accuracy_11: 0.3153 - dense_30_accuracy_12: 0.2500 - dense_30_accuracy_13: 0.2500 - dense_30_accuracy_14: 0.3146 - dense_30_accuracy_15: 0.3903 - dense_30_accuracy_16: 0.3375 - dense_30_accuracy_17: 0.3049 - dense_30_accuracy_18: 0.3590 - dense_30_accuracy_19: 0.2396 - dense_30_accuracy_2: 0.1625 - dense_30_accuracy_20: 0.3701 - dense_30_accuracy_21: 0.3354 - dense_30_accuracy_22: 0.3042 - dense_30_accuracy_23: 0.2507 - dense_30_accuracy_24: 0.3479 - dense_30_accuracy_25: 0.2500 - dense_30_accuracy_26: 0.3479 - dense_30_accuracy_27: 0.3694 - dense_30_accuracy_28: 0.3806 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1417 - dense_30_accuracy_4: 0.3368 - dense_30_accuracy_5: 0.3153 - dense_30_accuracy_6: 0.2833 - dense_30_accuracy_7: 0.3361 - dense_30_accuracy_8: 0.2819 - dense_30_accuracy_9: 0.2944 - dense_30_loss: 0.0000e+00 - loss: 76.1103
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.2715 - dense_30_accuracy_10: 0.3806 - dense_30_accuracy_11: 0.3792 - dense_30_accuracy_12: 0.2826 - dense_30_accuracy_13: 0.2625 - dense_30_accuracy_14: 0.3375 - dense_30_accuracy_15: 0.4333 - dense_30_accuracy_16: 0.4785 - dense_30_accuracy_17: 0.4333 - dense_30_accuracy_18: 0.3722 - dense_30_accuracy_19: 0.3264 - dense_30_accuracy_2: 0.1313 - dense_30_accuracy_20: 0.4028 - dense_30_accuracy_21: 0.3368 - dense_30_accuracy_22: 0.3153 - dense_30_accuracy_23: 0.3146 - dense_30_accuracy_24: 0.3708 - dense_30_accuracy_25: 0.2938 - dense_30_accuracy_26: 0.3597 - dense_30_accuracy_27: 0.4118 - dense_30_accuracy_28: 0.4889 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1424 - dense_30_accuracy_4: 0.3479 - dense_30_accuracy_5: 0.3799 - dense_30_accuracy_6: 0.3146 - dense_30_accuracy_7: 0.3049 - dense_30_accuracy_8: 0.2722 - dense_30_accuracy_9: 0.3375 - dense_30_loss: 0.0000e+00 - loss: 72.7849
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - dense_30_accuracy: 0.0875 - dense_30_accuracy_1: 0.3028 - dense_30_accuracy_10: 0.4243 - dense_30_accuracy_11: 0.3819 - dense_30_accuracy_12: 0.4021 - dense_30_accuracy_13: 0.2618 - dense_30_accuracy_14: 0.3917 - dense_30_accuracy_15: 0.4229 - dense_30_accuracy_16: 0.5444 - dense_30_accuracy_17: 0.4806 - dense_30_accuracy_18: 0.4132 - dense_30_accuracy_19: 0.3590 - dense_30_accuracy_2: 0.1729 - dense_30_accuracy_20: 0.4688 - dense_30_accuracy_21: 0.3917 - dense_30_accuracy_22: 0.3694 - dense_30_accuracy_23: 0.3576 - dense_30_accuracy_24: 0.3174 - dense_30_accuracy_25: 0.3354 - dense_30_accuracy_26: 0.3694 - dense_30_accuracy_27: 0.4792 - dense_30_accuracy_28: 0.4250 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1632 - dense_30_accuracy_4: 0.3486 - dense_30_accuracy_5: 0.3375 - dense_30_accuracy_6: 0.3049 - dense_30_accuracy_7: 0.3271 - dense_30_accuracy_8: 0.3153 - dense_30_accuracy_9: 0.3493 - dense_30_loss: 0.0000e+00 - loss: 69.2262
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - dense_30_accuracy: 0.0979 - dense_30_accuracy_1: 0.2826 - dense_30_accuracy_10: 0.4340 - dense_30_accuracy_11: 0.3812 - dense_30_accuracy_12: 0.3486 - dense_30_accuracy_13: 0.3257 - dense_30_accuracy_14: 0.3924 - dense_30_accuracy_15: 0.4139 - dense_30_accuracy_16: 0.5333 - dense_30_accuracy_17: 0.4785 - dense_30_accuracy_18: 0.5215 - dense_30_accuracy_19: 0.4139 - dense_30_accuracy_2: 0.2056 - dense_30_accuracy_20: 0.5431 - dense_30_accuracy_21: 0.3917 - dense_30_accuracy_22: 0.4132 - dense_30_accuracy_23: 0.3264 - dense_30_accuracy_24: 0.4035 - dense_30_accuracy_25: 0.3583 - dense_30_accuracy_26: 0.4792 - dense_30_accuracy_27: 0.5333 - dense_30_accuracy_28: 0.5333 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.1854 - dense_30_accuracy_4: 0.3382 - dense_30_accuracy_5: 0.4333 - dense_30_accuracy_6: 0.4014 - dense_30_accuracy_7: 0.3708 - dense_30_accuracy_8: 0.3806 - dense_30_accuracy_9: 0.4347 - dense_30_loss: 0.0000e+00 - loss: 66.2331
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dense_30_accuracy: 0.0979 - dense_30_accuracy_1: 0.2938 - dense_30_accuracy_10: 0.4674 - dense_30_accuracy_11: 0.4243 - dense_30_accuracy_12: 0.4674 - dense_30_accuracy_13: 0.3910 - dense_30_accuracy_14: 0.4889 - dense_30_accuracy_15: 0.5104 - dense_30_accuracy_16: 0.5972 - dense_30_accuracy_17: 0.5000 - dense_30_accuracy_18: 0.5958 - dense_30_accuracy_19: 0.3924 - dense_30_accuracy_2: 0.2069 - dense_30_accuracy_20: 0.4993 - dense_30_accuracy_21: 0.4361 - dense_30_accuracy_22: 0.4035 - dense_30_accuracy_23: 0.4222 - dense_30_accuracy_24: 0.4444 - dense_30_accuracy_25: 0.3472 - dense_30_accuracy_26: 0.4882 - dense_30_accuracy_27: 0.5542 - dense_30_accuracy_28: 0.5326 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.2590 - dense_30_accuracy_4: 0.3806 - dense_30_accuracy_5: 0.4451 - dense_30_accuracy_6: 0.3910 - dense_30_accuracy_7: 0.4347 - dense_30_accuracy_8: 0.4146 - dense_30_accuracy_9: 0.4569 - dense_30_loss: 0.0000e+00 - loss: 62.2569
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - dense_30_accuracy: 0.0979 - dense_30_accuracy_1: 0.3368 - dense_30_accuracy_10: 0.5208 - dense_30_accuracy_11: 0.4139 - dense_30_accuracy_12: 0.4785 - dense_30_accuracy_13: 0.3597 - dense_30_accuracy_14: 0.4792 - dense_30_accuracy_15: 0.5639 - dense_30_accuracy_16: 0.6424 - dense_30_accuracy_17: 0.6090 - dense_30_accuracy_18: 0.5222 - dense_30_accuracy_19: 0.3931 - dense_30_accuracy_2: 0.2069 - dense_30_accuracy_20: 0.4910 - dense_30_accuracy_21: 0.5111 - dense_30_accuracy_22: 0.5222 - dense_30_accuracy_23: 0.4667 - dense_30_accuracy_24: 0.4569 - dense_30_accuracy_25: 0.4229 - dense_30_accuracy_26: 0.5215 - dense_30_accuracy_27: 0.6188 - dense_30_accuracy_28: 0.6083 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.2722 - dense_30_accuracy_4: 0.4354 - dense_30_accuracy_5: 0.4458 - dense_30_accuracy_6: 0.4875 - dense_30_accuracy_7: 0.4132 - dense_30_accuracy_8: 0.4576 - dense_30_accuracy_9: 0.5215 - dense_30_loss: 0.0000e+00 - loss: 59.6782
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.3576 - dense_30_accuracy_10: 0.6076 - dense_30_accuracy_11: 0.4035 - dense_30_accuracy_12: 0.5764 - dense_30_accuracy_13: 0.4257 - dense_30_accuracy_14: 0.5111 - dense_30_accuracy_15: 0.5972 - dense_30_accuracy_16: 0.6736 - dense_30_accuracy_17: 0.6403 - dense_30_accuracy_18: 0.6201 - dense_30_accuracy_19: 0.5236 - dense_30_accuracy_2: 0.2292 - dense_30_accuracy_20: 0.6083 - dense_30_accuracy_21: 0.4896 - dense_30_accuracy_22: 0.5882 - dense_30_accuracy_23: 0.4785 - dense_30_accuracy_24: 0.4674 - dense_30_accuracy_25: 0.5118 - dense_30_accuracy_26: 0.6201 - dense_30_accuracy_27: 0.6632 - dense_30_accuracy_28: 0.6521 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.3063 - dense_30_accuracy_4: 0.5097 - dense_30_accuracy_5: 0.4799 - dense_30_accuracy_6: 0.4354 - dense_30_accuracy_7: 0.5757 - dense_30_accuracy_8: 0.5111 - dense_30_accuracy_9: 0.5778 - dense_30_loss: 0.0000e+00 - loss: 56.3484
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.3375 - dense_30_accuracy_10: 0.5549 - dense_30_accuracy_11: 0.6083 - dense_30_accuracy_12: 0.7264 - dense_30_accuracy_13: 0.6181 - dense_30_accuracy_14: 0.6958 - dense_30_accuracy_15: 0.6743 - dense_30_accuracy_16: 0.7597 - dense_30_accuracy_17: 0.6736 - dense_30_accuracy_18: 0.7056 - dense_30_accuracy_19: 0.6201 - dense_30_accuracy_2: 0.2819 - dense_30_accuracy_20: 0.6743 - dense_30_accuracy_21: 0.6417 - dense_30_accuracy_22: 0.7271 - dense_30_accuracy_23: 0.6083 - dense_30_accuracy_24: 0.5660 - dense_30_accuracy_25: 0.5111 - dense_30_accuracy_26: 0.6417 - dense_30_accuracy_27: 0.7389 - dense_30_accuracy_28: 0.7396 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.4340 - dense_30_accuracy_4: 0.5340 - dense_30_accuracy_5: 0.5854 - dense_30_accuracy_6: 0.5007 - dense_30_accuracy_7: 0.5333 - dense_30_accuracy_8: 0.5771 - dense_30_accuracy_9: 0.6194 - dense_30_loss: 0.0000e+00 - loss: 52.4901
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dense_30_accuracy: 0.0979 - dense_30_accuracy_1: 0.4028 - dense_30_accuracy_10: 0.7382 - dense_30_accuracy_11: 0.6639 - dense_30_accuracy_12: 0.7389 - dense_30_accuracy_13: 0.5785 - dense_30_accuracy_14: 0.7174 - dense_30_accuracy_15: 0.6868 - dense_30_accuracy_16: 0.7931 - dense_30_accuracy_17: 0.6750 - dense_30_accuracy_18: 0.7396 - dense_30_accuracy_19: 0.6743 - dense_30_accuracy_2: 0.2826 - dense_30_accuracy_20: 0.7069 - dense_30_accuracy_21: 0.7076 - dense_30_accuracy_22: 0.7729 - dense_30_accuracy_23: 0.5875 - dense_30_accuracy_24: 0.7806 - dense_30_accuracy_25: 0.6090 - dense_30_accuracy_26: 0.7083 - dense_30_accuracy_27: 0.6972 - dense_30_accuracy_28: 0.6965 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 0.5431 - dense_30_accuracy_4: 0.5979 - dense_30_accuracy_5: 0.6403 - dense_30_accuracy_6: 0.5549 - dense_30_accuracy_7: 0.6097 - dense_30_accuracy_8: 0.6194 - dense_30_accuracy_9: 0.7181 - dense_30_loss: 0.0000e+00 - loss: 50.4085
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dense_30_accuracy: 0.0875 - dense_30_accuracy_1: 0.4139 - dense_30_accuracy_10: 0.6639 - dense_30_accuracy_11: 0.7063 - dense_30_accuracy_12: 0.7500 - dense_30_accuracy_13: 0.6417 - dense_30_accuracy_14: 0.7611 - dense_30_accuracy_15: 0.7507 - dense_30_accuracy_16: 0.8160 - dense_30_accuracy_17: 0.7611 - dense_30_accuracy_18: 0.7486 - dense_30_accuracy_19: 0.6743 - dense_30_accuracy_2: 0.3799 - dense_30_accuracy_20: 0.8354 - dense_30_accuracy_21: 0.7597 - dense_30_accuracy_22: 0.8694 - dense_30_accuracy_23: 0.6958 - dense_30_accuracy_24: 0.7493 - dense_30_accuracy_25: 0.6424 - dense_30_accuracy_26: 0.7069 - dense_30_accuracy_27: 0.7611 - dense_30_accuracy_28: 0.8681 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 0.5757 - dense_30_accuracy_4: 0.5986 - dense_30_accuracy_5: 0.5868 - dense_30_accuracy_6: 0.6097 - dense_30_accuracy_7: 0.6632 - dense_30_accuracy_8: 0.5882 - dense_30_accuracy_9: 0.7812 - dense_30_loss: 0.0000e+00 - loss: 46.3735
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - dense_30_accuracy: 0.0771 - dense_30_accuracy_1: 0.4667 - dense_30_accuracy_10: 0.7722 - dense_30_accuracy_11: 0.7299 - dense_30_accuracy_12: 0.8486 - dense_30_accuracy_13: 0.7292 - dense_30_accuracy_14: 0.7826 - dense_30_accuracy_15: 0.7722 - dense_30_accuracy_16: 0.9021 - dense_30_accuracy_17: 0.8160 - dense_30_accuracy_18: 0.7931 - dense_30_accuracy_19: 0.6965 - dense_30_accuracy_2: 0.3708 - dense_30_accuracy_20: 0.8583 - dense_30_accuracy_21: 0.7625 - dense_30_accuracy_22: 0.9556 - dense_30_accuracy_23: 0.7174 - dense_30_accuracy_24: 0.7604 - dense_30_accuracy_25: 0.7076 - dense_30_accuracy_26: 0.7937 - dense_30_accuracy_27: 0.8264 - dense_30_accuracy_28: 0.9132 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 0.5861 - dense_30_accuracy_4: 0.6312 - dense_30_accuracy_5: 0.6090 - dense_30_accuracy_6: 0.6736 - dense_30_accuracy_7: 0.6632 - dense_30_accuracy_8: 0.7389 - dense_30_accuracy_9: 0.7715 - dense_30_loss: 0.0000e+00 - loss: 44.1547
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.4465 - dense_30_accuracy_10: 0.8160 - dense_30_accuracy_11: 0.8035 - dense_30_accuracy_12: 0.8799 - dense_30_accuracy_13: 0.8465 - dense_30_accuracy_14: 0.8257 - dense_30_accuracy_15: 0.8354 - dense_30_accuracy_16: 0.9021 - dense_30_accuracy_17: 0.9007 - dense_30_accuracy_18: 0.8792 - dense_30_accuracy_19: 0.8361 - dense_30_accuracy_2: 0.4236 - dense_30_accuracy_20: 0.8583 - dense_30_accuracy_21: 0.8465 - dense_30_accuracy_22: 0.9243 - dense_30_accuracy_23: 0.7500 - dense_30_accuracy_24: 0.7403 - dense_30_accuracy_25: 0.7708 - dense_30_accuracy_26: 0.8681 - dense_30_accuracy_27: 0.8694 - dense_30_accuracy_28: 0.9021 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 0.6083 - dense_30_accuracy_4: 0.6944 - dense_30_accuracy_5: 0.7174 - dense_30_accuracy_6: 0.6514 - dense_30_accuracy_7: 0.7278 - dense_30_accuracy_8: 0.8257 - dense_30_accuracy_9: 0.8049 - dense_30_loss: 0.0000e+00 - loss: 39.8864
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dense_30_accuracy: 0.0875 - dense_30_accuracy_1: 0.4472 - dense_30_accuracy_10: 0.8479 - dense_30_accuracy_11: 0.7729 - dense_30_accuracy_12: 0.8694 - dense_30_accuracy_13: 0.8910 - dense_30_accuracy_14: 0.8042 - dense_30_accuracy_15: 0.8486 - dense_30_accuracy_16: 0.9667 - dense_30_accuracy_17: 0.8382 - dense_30_accuracy_18: 0.8583 - dense_30_accuracy_19: 0.7625 - dense_30_accuracy_2: 0.4778 - dense_30_accuracy_20: 0.8493 - dense_30_accuracy_21: 0.7944 - dense_30_accuracy_22: 0.9569 - dense_30_accuracy_23: 0.8486 - dense_30_accuracy_24: 0.8917 - dense_30_accuracy_25: 0.8694 - dense_30_accuracy_26: 0.8479 - dense_30_accuracy_27: 0.8910 - dense_30_accuracy_28: 0.9243 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 0.6201 - dense_30_accuracy_4: 0.6958 - dense_30_accuracy_5: 0.7507 - dense_30_accuracy_6: 0.7076 - dense_30_accuracy_7: 0.7826 - dense_30_accuracy_8: 0.8049 - dense_30_accuracy_9: 0.8160 - dense_30_loss: 0.0000e+00 - loss: 38.7750
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.4674 - dense_30_accuracy_10: 0.8694 - dense_30_accuracy_11: 0.8250 - dense_30_accuracy_12: 0.8812 - dense_30_accuracy_13: 0.9132 - dense_30_accuracy_14: 0.8694 - dense_30_accuracy_15: 0.8465 - dense_30_accuracy_16: 0.9458 - dense_30_accuracy_17: 0.8806 - dense_30_accuracy_18: 0.8257 - dense_30_accuracy_19: 0.8257 - dense_30_accuracy_2: 0.4569 - dense_30_accuracy_20: 0.8590 - dense_30_accuracy_21: 0.9021 - dense_30_accuracy_22: 0.9132 - dense_30_accuracy_23: 0.9021 - dense_30_accuracy_24: 0.9125 - dense_30_accuracy_25: 0.8479 - dense_30_accuracy_26: 0.8472 - dense_30_accuracy_27: 0.8583 - dense_30_accuracy_28: 0.9563 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 0.6521 - dense_30_accuracy_4: 0.7174 - dense_30_accuracy_5: 0.7937 - dense_30_accuracy_6: 0.7604 - dense_30_accuracy_7: 0.8375 - dense_30_accuracy_8: 0.8694 - dense_30_accuracy_9: 0.9132 - dense_30_loss: 0.0000e+00 - loss: 35.2807
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.4250 - dense_30_accuracy_10: 0.8472 - dense_30_accuracy_11: 0.8160 - dense_30_accuracy_12: 0.9458 - dense_30_accuracy_13: 0.9132 - dense_30_accuracy_14: 0.8590 - dense_30_accuracy_15: 0.8056 - dense_30_accuracy_16: 0.9563 - dense_30_accuracy_17: 0.8917 - dense_30_accuracy_18: 0.9243 - dense_30_accuracy_19: 0.7937 - dense_30_accuracy_2: 0.5868 - dense_30_accuracy_20: 0.9028 - dense_30_accuracy_21: 0.9132 - dense_30_accuracy_22: 0.9778 - dense_30_accuracy_23: 0.9458 - dense_30_accuracy_24: 0.9569 - dense_30_accuracy_25: 0.9021 - dense_30_accuracy_26: 0.8694 - dense_30_accuracy_27: 0.9007 - dense_30_accuracy_28: 0.9569 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 0.7486 - dense_30_accuracy_4: 0.7396 - dense_30_accuracy_5: 0.8042 - dense_30_accuracy_6: 0.8465 - dense_30_accuracy_7: 0.8583 - dense_30_accuracy_8: 0.8472 - dense_30_accuracy_9: 0.8924 - dense_30_loss: 0.0000e+00 - loss: 32.8514
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dense_30_accuracy: 0.0868 - dense_30_accuracy_1: 0.4250 - dense_30_accuracy_10: 0.8917 - dense_30_accuracy_11: 0.8264 - dense_30_accuracy_12: 0.9243 - dense_30_accuracy_13: 0.9569 - dense_30_accuracy_14: 0.8799 - dense_30_accuracy_15: 0.8701 - dense_30_accuracy_16: 0.9778 - dense_30_accuracy_17: 0.9236 - dense_30_accuracy_18: 0.8806 - dense_30_accuracy_19: 0.8590 - dense_30_accuracy_2: 0.5764 - dense_30_accuracy_20: 0.9028 - dense_30_accuracy_21: 0.9347 - dense_30_accuracy_22: 0.9674 - dense_30_accuracy_23: 0.9354 - dense_30_accuracy_24: 0.9458 - dense_30_accuracy_25: 0.9021 - dense_30_accuracy_26: 0.9458 - dense_30_accuracy_27: 0.8903 - dense_30_accuracy_28: 0.9674 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 0.7604 - dense_30_accuracy_4: 0.7396 - dense_30_accuracy_5: 0.8486 - dense_30_accuracy_6: 0.8375 - dense_30_accuracy_7: 0.8806 - dense_30_accuracy_8: 0.8375 - dense_30_accuracy_9: 0.9132 - dense_30_loss: 0.0000e+00 - loss: 30.5578
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dense_30_accuracy: 0.0542 - dense_30_accuracy_1: 0.4681 - dense_30_accuracy_10: 0.9340 - dense_30_accuracy_11: 0.8375 - dense_30_accuracy_12: 0.9674 - dense_30_accuracy_13: 0.9569 - dense_30_accuracy_14: 0.9236 - dense_30_accuracy_15: 0.9021 - dense_30_accuracy_16: 0.9889 - dense_30_accuracy_17: 0.9347 - dense_30_accuracy_18: 0.9458 - dense_30_accuracy_19: 0.8583 - dense_30_accuracy_2: 0.5979 - dense_30_accuracy_20: 0.9028 - dense_30_accuracy_21: 0.9139 - dense_30_accuracy_22: 0.9674 - dense_30_accuracy_23: 0.9458 - dense_30_accuracy_24: 0.9785 - dense_30_accuracy_25: 0.9354 - dense_30_accuracy_26: 0.8701 - dense_30_accuracy_27: 0.8806 - dense_30_accuracy_28: 0.9674 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 0.7826 - dense_30_accuracy_4: 0.8257 - dense_30_accuracy_5: 0.8701 - dense_30_accuracy_6: 0.8264 - dense_30_accuracy_7: 0.8806 - dense_30_accuracy_8: 0.8799 - dense_30_accuracy_9: 0.9563 - dense_30_loss: 0.0000e+00 - loss: 28.3271
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dense_30_accuracy: 0.1403 - dense_30_accuracy_1: 0.4681 - dense_30_accuracy_10: 0.9451 - dense_30_accuracy_11: 0.8063 - dense_30_accuracy_12: 0.9569 - dense_30_accuracy_13: 0.9785 - dense_30_accuracy_14: 0.9028 - dense_30_accuracy_15: 0.9132 - dense_30_accuracy_16: 0.9889 - dense_30_accuracy_17: 0.9451 - dense_30_accuracy_18: 0.9563 - dense_30_accuracy_19: 0.8910 - dense_30_accuracy_2: 0.5875 - dense_30_accuracy_20: 0.9028 - dense_30_accuracy_21: 0.9451 - dense_30_accuracy_22: 0.9674 - dense_30_accuracy_23: 0.9458 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 0.9778 - dense_30_accuracy_26: 0.9139 - dense_30_accuracy_27: 0.9444 - dense_30_accuracy_28: 0.9674 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 0.8049 - dense_30_accuracy_4: 0.7722 - dense_30_accuracy_5: 0.8917 - dense_30_accuracy_6: 0.8910 - dense_30_accuracy_7: 0.9014 - dense_30_accuracy_8: 0.8806 - dense_30_accuracy_9: 0.9563 - dense_30_loss: 0.0000e+00 - loss: 26.1754
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - dense_30_accuracy: 0.0868 - dense_30_accuracy_1: 0.4472 - dense_30_accuracy_10: 0.9458 - dense_30_accuracy_11: 0.8590 - dense_30_accuracy_12: 0.9458 - dense_30_accuracy_13: 0.9889 - dense_30_accuracy_14: 0.9125 - dense_30_accuracy_15: 0.9243 - dense_30_accuracy_16: 0.9785 - dense_30_accuracy_17: 0.9243 - dense_30_accuracy_18: 0.9674 - dense_30_accuracy_19: 0.9028 - dense_30_accuracy_2: 0.6514 - dense_30_accuracy_20: 0.9347 - dense_30_accuracy_21: 0.9563 - dense_30_accuracy_22: 0.9785 - dense_30_accuracy_23: 0.9563 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 0.9354 - dense_30_accuracy_26: 0.9674 - dense_30_accuracy_27: 0.8812 - dense_30_accuracy_28: 0.9674 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 0.8049 - dense_30_accuracy_4: 0.8479 - dense_30_accuracy_5: 0.9347 - dense_30_accuracy_6: 0.8917 - dense_30_accuracy_7: 0.8910 - dense_30_accuracy_8: 0.8694 - dense_30_accuracy_9: 0.9347 - dense_30_loss: 0.0000e+00 - loss: 24.4024
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dense_30_accuracy: 0.0868 - dense_30_accuracy_1: 0.4681 - dense_30_accuracy_10: 0.9458 - dense_30_accuracy_11: 0.8583 - dense_30_accuracy_12: 0.9889 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 0.9569 - dense_30_accuracy_15: 0.9236 - dense_30_accuracy_16: 0.9785 - dense_30_accuracy_17: 0.9347 - dense_30_accuracy_18: 0.9569 - dense_30_accuracy_19: 0.9236 - dense_30_accuracy_2: 0.6514 - dense_30_accuracy_20: 0.9458 - dense_30_accuracy_21: 0.9354 - dense_30_accuracy_22: 0.9785 - dense_30_accuracy_23: 0.9458 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 0.9667 - dense_30_accuracy_27: 0.9569 - dense_30_accuracy_28: 0.9674 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 0.8583 - dense_30_accuracy_4: 0.9125 - dense_30_accuracy_5: 0.9236 - dense_30_accuracy_6: 0.9451 - dense_30_accuracy_7: 0.8806 - dense_30_accuracy_8: 0.8917 - dense_30_accuracy_9: 0.9243 - dense_30_loss: 0.0000e+00 - loss: 22.2110
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dense_30_accuracy: 0.0972 - dense_30_accuracy_1: 0.4785 - dense_30_accuracy_10: 0.9667 - dense_30_accuracy_11: 0.9132 - dense_30_accuracy_12: 0.9785 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 0.9785 - dense_30_accuracy_15: 0.9354 - dense_30_accuracy_16: 0.9785 - dense_30_accuracy_17: 0.9354 - dense_30_accuracy_18: 0.9569 - dense_30_accuracy_19: 0.9243 - dense_30_accuracy_2: 0.6521 - dense_30_accuracy_20: 0.9458 - dense_30_accuracy_21: 0.9569 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 0.9778 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 0.9674 - dense_30_accuracy_27: 0.9785 - dense_30_accuracy_28: 0.9889 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 0.8799 - dense_30_accuracy_4: 0.9021 - dense_30_accuracy_5: 0.9236 - dense_30_accuracy_6: 0.9556 - dense_30_accuracy_7: 0.9563 - dense_30_accuracy_8: 0.9458 - dense_30_accuracy_9: 0.9347 - dense_30_loss: 0.0000e+00 - loss: 20.6078
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dense_30_accuracy: 0.0868 - dense_30_accuracy_1: 0.4889 - dense_30_accuracy_10: 0.9451 - dense_30_accuracy_11: 0.9347 - dense_30_accuracy_12: 0.9889 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 0.9674 - dense_30_accuracy_15: 0.9785 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 0.9569 - dense_30_accuracy_18: 0.9785 - dense_30_accuracy_19: 0.9458 - dense_30_accuracy_2: 0.6847 - dense_30_accuracy_20: 0.9785 - dense_30_accuracy_21: 0.9569 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 0.9569 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 0.9889 - dense_30_accuracy_26: 0.9785 - dense_30_accuracy_27: 1.0000 - dense_30_accuracy_28: 0.9785 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 0.9021 - dense_30_accuracy_4: 0.9340 - dense_30_accuracy_5: 0.9132 - dense_30_accuracy_6: 0.9667 - dense_30_accuracy_7: 0.9674 - dense_30_accuracy_8: 0.9889 - dense_30_accuracy_9: 0.9347 - dense_30_loss: 0.0000e+00 - loss: 19.2803
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dense_30_accuracy: 0.0868 - dense_30_accuracy_1: 0.5528 - dense_30_accuracy_10: 0.9785 - dense_30_accuracy_11: 0.9674 - dense_30_accuracy_12: 0.9785 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 0.9569 - dense_30_accuracy_15: 0.9785 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 0.9674 - dense_30_accuracy_18: 0.9889 - dense_30_accuracy_19: 0.9563 - dense_30_accuracy_2: 0.7382 - dense_30_accuracy_20: 0.9785 - dense_30_accuracy_21: 0.9889 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 0.9569 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 0.9785 - dense_30_accuracy_28: 0.9889 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 0.9347 - dense_30_accuracy_4: 0.9347 - dense_30_accuracy_5: 0.9028 - dense_30_accuracy_6: 0.9785 - dense_30_accuracy_7: 0.9674 - dense_30_accuracy_8: 0.9785 - dense_30_accuracy_9: 0.9458 - dense_30_loss: 0.0000e+00 - loss: 17.7198
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dense_30_accuracy: 0.0764 - dense_30_accuracy_1: 0.5215 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 0.9889 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 0.9889 - dense_30_accuracy_15: 0.9889 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 0.9778 - dense_30_accuracy_18: 0.9889 - dense_30_accuracy_19: 0.9778 - dense_30_accuracy_2: 0.7389 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 0.9889 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 0.9569 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 1.0000 - dense_30_accuracy_28: 1.0000 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 0.9667 - dense_30_accuracy_4: 0.9243 - dense_30_accuracy_5: 0.9354 - dense_30_accuracy_6: 0.9785 - dense_30_accuracy_7: 0.9785 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 0.9674 - dense_30_loss: 0.0000e+00 - loss: 16.3809
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dense_30_accuracy: 0.1076 - dense_30_accuracy_1: 0.5111 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 0.9785 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 0.9785 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 0.9889 - dense_30_accuracy_18: 0.9785 - dense_30_accuracy_19: 0.9674 - dense_30_accuracy_2: 0.7285 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 0.9785 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 0.9778 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 1.0000 - dense_30_accuracy_28: 1.0000 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 0.9569 - dense_30_accuracy_4: 0.9243 - dense_30_accuracy_5: 0.9889 - dense_30_accuracy_6: 0.9785 - dense_30_accuracy_7: 0.9889 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 15.5157
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dense_30_accuracy: 0.0764 - dense_30_accuracy_1: 0.4799 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 0.9889 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 0.9889 - dense_30_accuracy_2: 0.7396 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 0.9785 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 1.0000 - dense_30_accuracy_28: 1.0000 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 0.9674 - dense_30_accuracy_4: 0.9458 - dense_30_accuracy_5: 0.9785 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 0.9785 - dense_30_accuracy_8: 0.9889 - dense_30_accuracy_9: 0.9889 - dense_30_loss: 0.0000e+00 - loss: 14.7916
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dense_30_accuracy: 0.0868 - dense_30_accuracy_1: 0.5319 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 0.9889 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 0.9889 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 0.9785 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 0.9785 - dense_30_accuracy_2: 0.7722 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 0.9785 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 1.0000 - dense_30_accuracy_28: 1.0000 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 0.9674 - dense_30_accuracy_4: 0.9354 - dense_30_accuracy_5: 0.9889 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 0.9889 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 0.9889 - dense_30_loss: 0.0000e+00 - loss: 13.7781
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dense_30_accuracy: 0.0660 - dense_30_accuracy_1: 0.5326 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 0.9889 - dense_30_accuracy_18: 0.9889 - dense_30_accuracy_19: 0.9889 - dense_30_accuracy_2: 0.8257 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 0.9889 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 1.0000 - dense_30_accuracy_28: 1.0000 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 0.9778 - dense_30_accuracy_4: 0.9569 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 0.9889 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 0.9889 - dense_30_loss: 0.0000e+00 - loss: 12.8988
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - dense_30_accuracy: 0.0868 - dense_30_accuracy_1: 0.5118 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 0.9785 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 0.9785 - dense_30_accuracy_2: 0.8035 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 1.0000 - dense_30_accuracy_28: 1.0000 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 0.9569 - dense_30_accuracy_4: 0.9889 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 0.9785 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 0.9785 - dense_30_loss: 0.0000e+00 - loss: 12.6835
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dense_30_accuracy: 0.0868 - dense_30_accuracy_1: 0.5750 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 0.9785 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 0.9785 - dense_30_accuracy_2: 0.7931 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 1.0000 - dense_30_accuracy_28: 1.0000 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 0.9778 - dense_30_accuracy_4: 0.9889 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 0.9889 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 11.7174
# Epoch 48/100
# ...
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - dense_30_accuracy: 0.1187 - dense_30_accuracy_1: 0.6951 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 1.0000 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 1.0000 - dense_30_accuracy_28: 0.9889 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 6.8280
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dense_30_accuracy: 0.0771 - dense_30_accuracy_1: 0.6847 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 0.9785 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 0.9569 - dense_30_accuracy_27: 0.9785 - dense_30_accuracy_28: 0.9139 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 8.4288
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dense_30_accuracy: 0.1187 - dense_30_accuracy_1: 0.7063 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 0.9889 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 0.9889 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 1.0000 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 1.0000 - dense_30_accuracy_28: 1.0000 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 7.2293
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.7056 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 0.9889 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 0.9785 - dense_30_accuracy_27: 0.9569 - dense_30_accuracy_28: 0.9569 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 8.5372
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.6535 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 0.9889 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 0.9785 - dense_30_accuracy_20: 0.9889 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 0.9889 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 0.9785 - dense_30_accuracy_28: 1.0000 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 7.3807
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.6847 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 0.9889 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 0.9889 - dense_30_accuracy_28: 1.0000 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 7.4214
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dense_30_accuracy: 0.0875 - dense_30_accuracy_1: 0.6639 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 0.9889 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 0.9785 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 0.9889 - dense_30_accuracy_28: 0.9569 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 7.6610
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - dense_30_accuracy: 0.0979 - dense_30_accuracy_1: 0.7382 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 0.9785 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 0.9785 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 0.9674 - dense_30_accuracy_28: 0.9785 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 7.1967
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.6965 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 0.9785 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 1.0000 - dense_30_accuracy_28: 0.9785 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 7.3272
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - dense_30_accuracy: 0.0771 - dense_30_accuracy_1: 0.7174 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 1.0000 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 0.9889 - dense_30_accuracy_27: 0.9674 - dense_30_accuracy_28: 0.9785 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 7.3169
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dense_30_accuracy: 0.0771 - dense_30_accuracy_1: 0.7069 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 1.0000 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 1.0000 - dense_30_accuracy_28: 0.9889 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 6.7730
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dense_30_accuracy: 0.0875 - dense_30_accuracy_1: 0.7264 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 0.9889 - dense_30_accuracy_19: 0.9889 - dense_30_accuracy_2: 0.9889 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 0.9674 - dense_30_accuracy_28: 0.9569 - dense_30_accuracy_29: 0.0000e+00 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 7.4253
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.7167 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 0.9889 - dense_30_accuracy_20: 0.9889 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 1.0000 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 0.9778 - dense_30_accuracy_28: 1.0000 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 6.5777
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.6965 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 0.9785 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 0.9785 - dense_30_accuracy_20: 0.9785 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 0.9785 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 0.9785 - dense_30_accuracy_25: 0.9785 - dense_30_accuracy_26: 1.0000 - dense_30_accuracy_27: 0.9569 - dense_30_accuracy_28: 0.9458 - dense_30_accuracy_29: 0.0111 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 7.8553
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dense_30_accuracy: 0.1083 - dense_30_accuracy_1: 0.7160 - dense_30_accuracy_10: 1.0000 - dense_30_accuracy_11: 1.0000 - dense_30_accuracy_12: 1.0000 - dense_30_accuracy_13: 1.0000 - dense_30_accuracy_14: 1.0000 - dense_30_accuracy_15: 1.0000 - dense_30_accuracy_16: 1.0000 - dense_30_accuracy_17: 1.0000 - dense_30_accuracy_18: 1.0000 - dense_30_accuracy_19: 1.0000 - dense_30_accuracy_2: 0.9785 - dense_30_accuracy_20: 1.0000 - dense_30_accuracy_21: 1.0000 - dense_30_accuracy_22: 1.0000 - dense_30_accuracy_23: 1.0000 - dense_30_accuracy_24: 1.0000 - dense_30_accuracy_25: 0.9569 - dense_30_accuracy_26: 0.9243 - dense_30_accuracy_27: 1.0000 - dense_30_accuracy_28: 0.9458 - dense_30_accuracy_29: 0.0215 - dense_30_accuracy_3: 1.0000 - dense_30_accuracy_4: 1.0000 - dense_30_accuracy_5: 1.0000 - dense_30_accuracy_6: 1.0000 - dense_30_accuracy_7: 1.0000 - dense_30_accuracy_8: 1.0000 - dense_30_accuracy_9: 1.0000 - dense_30_loss: 0.0000e+00 - loss: 7.4833

# %% [markdown]
# ## 3. Generate Music
#
# <img src="images/music_gen.png" height=500/>

# %%
class ArgMaxLayer(tf.keras.Layer):
    def call(self, x):
        return tf.math.argmax(x, axis=-1)

class OneHotLayer(tf.keras.Layer):
    def call(self, x):
        return tf.one_hot(x, n_values)
    

def music_inference_model(LSTM_cell, densor, Ty=100):
    """
    Uses the trained "LSTM_cell" and "densor" from model() to generate a sequence of values.
    
    Arguments:
    LSTM_cell -- the trained "LSTM_cell" from model(), Keras layer object
    densor -- the trained "densor" from model(), Keras layer object
    Ty -- integer, number of time steps to generate
    
    Returns:
    inference_model -- Keras model instance
    """
    
    # Get the shape of input values
    n_values = densor.units
    # Get the number of the hidden state vector
    n_a = LSTM_cell.units
    
    # Define the input of your model with a shape 
    x0 = Input(shape=(1, n_values))
    
    # Define s0, initial hidden state for the decoder LSTM
    a0 = Input(shape=(n_a,), name='a0')
    c0 = Input(shape=(n_a,), name='c0')
    a = a0
    c = c0
    x = x0

    # Step 1: Create an empty list of "outputs" to later store your predicted values (≈1 line)
    outputs = []
    
    # Step 2: Loop over Ty and generate a value at every time step
    for t in range(Ty): # Có thẻ thay đổi Ty tùy ý theo độ dài mong muốn. Tại một time step t:
        # Đưa x^t, a^{t-1}, c^{t-1} vào LSTM cell để tính a^t, c^t, đều có shape (1, n_a)=(1, 64)
        # Step 2.A: Perform one step of LSTM_cell. Use "x", not "x0" (≈1 line)
        a, _, c = LSTM_cell(x, initial_state=[a, c])
        
        # Tính y^t, có shape (1, n_y)=(1, 90)
        # Step 2.B: Apply Dense layer to the hidden state output of the LSTM_cell (≈1 line)
        out = densor(a)
        # Step 2.C: Append the prediction "out" to "outputs". out.shape = (None, 90) (≈1 line)
        outputs.append(out)
        
        # out là một prob vector, ta lấy index tại giá trị lớn nhất, rồi tạo môt one-hot vector từ index đó, chính là x^{(t+1)}
        # Step 2.D: 
        # Select the next value according to "out",
        # Set "x" to be the one-hot representation of the selected value
        # See instructions above.
        x = ArgMaxLayer()(out)
        x = OneHotLayer()(x)

        
    # Step 3: Create model instance with the correct "inputs" and "outputs" (≈1 line)
    inference_model = Model(inputs=[x0, a0, c0], outputs=outputs)
    
    ### END CODE HERE ###
    
    return inference_model

# %%
inference_model = music_inference_model(LSTM_cell, densor, Ty = 50)
# inference_model.summary()

# %%
x_initializer = np.zeros((1, 1, n_values))
a_initializer = np.zeros((1, n_a))
c_initializer = np.zeros((1, n_a))

def predict_and_sample(inference_model, x_initializer = x_initializer, a_initializer = a_initializer, 
                       c_initializer = c_initializer):
    n_values = x_initializer.shape[2]
    
    # Step 1: Use your inference model to predict an output sequence given x_initializer, a_initializer and c_initializer.
    pred = inference_model.predict([x_initializer, a_initializer, c_initializer]) # pred là list có len=T_y=50, mỗi element có shape (1, 90)
    
    # Lấy ra các indices là vị trí có giá trị lớn nhất tại các time steps
    # Step 2: Convert "pred" into an np.array() of indices with the maximum probabilities
    indices = np.argmax(pred, axis = -1) # indices.shape=(T_y, 1)=(50, 1)

    # Chuyển indices thành các one-hot vectors, có shape (T_y, n_y)=(50, 90)
    # Step 3: Convert indices to one-hot vectors, the shape of the results should be (Ty, n_values)
    results = to_categorical(indices, num_classes=n_values)
    
    return results, indices

# %%
results, indices = predict_and_sample(inference_model, x_initializer, a_initializer, c_initializer)

print("np.argmax(results[12]) =", np.argmax(results[12]))
print("np.argmax(results[17]) =", np.argmax(results[17]))
print("list(indices[12:18]) =", list(indices[12:18]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# np.argmax(results[12]) = 13
# np.argmax(results[17]) = 35
# list(indices[12:18]) = [array([13]), array([13]), array([13]), array([13]), array([35]), array([35])]

# %%
out_stream = generate_music(inference_model, indices_values, chords)
# Out:
# Predicting new values for different set of chords.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Generated 45 sounds using the predicted values for the set of chords ("1") and after pruning
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Generated 46 sounds using the predicted values for the set of chords ("2") and after pruning
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Generated 48 sounds using the predicted values for the set of chords ("3") and after pruning
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Generated 45 sounds using the predicted values for the set of chords ("4") and after pruning
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Generated 44 sounds using the predicted values for the set of chords ("5") and after pruning
# Your generated music is saved in output/my_music.midi

# %%
mid2wav('output/my_music.midi')
IPython.display.Audio('./output/rendered.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
